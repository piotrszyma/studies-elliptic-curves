# %%
import csv
import dataclasses
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

INPUT_PATH = 'pollard_rho_affine_20_out.csv'

# %%
@dataclasses.dataclass
class Row:
    x: int
    y: int
    type_: str


rows = []

with open(INPUT_PATH, newline="") as csvfile:
    raw_rows = csv.reader(csvfile, delimiter=";")

    for row in raw_rows:
        try:
            type_, x, y = row
        except ValueError:
            continue

        x = int(x)
        y = int(y)
        rows.append(Row(type_=type_, x=x, y=y))

max_x = max(row.x for row in rows)
max_y = max(row.y for row in rows)

# %%
plt.scatter([row.x for row in rows], [row.y for row in rows], s=2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = 714855
b = 392766
SIZE = 211231123232315000

y, x = np.ogrid[-SIZE:SIZE:100j, -SIZE:SIZE:100j]
plt.contour(x.ravel(), y.ravel(), pow(y, 2) - pow(x, 3) - x * a - b, [0])
# plt.grid()
# plt.show()

# %%
import numpy as np


# evenly sampled time at 200ms intervals
a = 714855
b = 392766
x = np.arange(10, 100000, 1)
field_order = 749149
# red dashes, blue squares and green triangles
# plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
# plt.show()

# y^{2}=x^{3}+ax+b

x = np.mod(x, field_order)
y = np.mod(np.sqrt(np.power(x, 3) + a * x + b), field_order)

# %%
plt.plot(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
